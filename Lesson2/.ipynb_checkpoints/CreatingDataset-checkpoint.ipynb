# %% [markdown]
# # Creating own Dataset from images.google URLs

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# ## in images.google.com
# * search for the required images and must include string int quotes
# * scroll till u see the show more results and you'll have 400 images, if click that and scroll itll be 700
# * when you have scrolled paste the following js code in browser console
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```
# * this will take all the URLs and gives a csv/text file to downalod with all the URLs

# %% [markdown]
# ### Path Class cmd line commands

# %%
Path('data').mkdir()

# %%
Path('data/venomous').mkdir()

# %%
Path('data/non_venomous').mkdir()

# %% [markdown]
# ## Classes for the classification

# %%
classes = ['venomous','non_venomous']

# %% [markdown]
# ### Taking the path of all the species as a list to download in a loop

# %%
list1 = Path('VenomousSnakesURLs').ls()
dest = Path('data/venomous')
list2 = Path('NonVenomousSnakesURLs').ls()
dest2 = Path('data/non_venomous')

# %% [markdown]
# ## Under vision.data
# ### download_images()
# * Downloads images <br> param 1 : url or list <br> param 2 : destination path <br> param 3 : max pics to be dowloaded
#
# ### verify_images()
# * try all the images in the path whether can it opened or not <br> param 1 : path of the dorectory to check <br> param 2 : bool to either to delete them if they are broken <br> param 3 : max_size to resize with the same ration but both sides less than the max size

# %%
for i in list1:
    download_images(i, dest, max_pics=400)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:37<00:00]
#     </div>
# Error x-raw-image:///c57891cc32621f36d927633ce3ec3c971e3d7e13196172049b69cb633c5d1bfc No connection adapters were found for 'x-raw-image:///c57891cc32621f36d927633ce3ec3c971e3d7e13196172049b69cb633c5d1bfc'
# Error x-raw-image:///f0e9f7c94e97398938d48f391021e1ea5e9acb311e4a4f51f6bd31dad9e4c778 No connection adapters were found for 'x-raw-image:///f0e9f7c94e97398938d48f391021e1ea5e9acb311e4a4f51f6bd31dad9e4c778'
# Error x-raw-image:///de96e227676a6658cb99825856c7acabf4e347992160e9d712be70903fded014 No connection adapters were found for 'x-raw-image:///de96e227676a6658cb99825856c7acabf4e347992160e9d712be70903fded014'
# Error http://i913.photobucket.com/albums/ac333/BlakesLife/BushcraftOz/IMGP9510.jpg HTTPConnectionPool(host='i913.photobucket.com', port=80): Read timed out. (read timeout=4)
# Error https://thesnake.review/wp-content/uploads/2018/06/africa-images-rhsafaritalknet-show-mainland-tiger-snake-us-your-s-and-crocs-etc-page-africa-images-rhsafaritalknet-notechis-scutatus-the-second-indiviu.jpg HTTPSConnectionPool(host='thesnake.review', port=443): Max retries exceeded with url: /wp-content/uploads/2018/06/africa-images-rhsafaritalknet-show-mainland-tiger-snake-us-your-s-and-crocs-etc-page-africa-images-rhsafaritalknet-notechis-scutatus-the-second-indiviu.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feb79d3b710>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
# Error x-raw-image:///887b36b648062e2adb409efa85609394835b1076e321bf76e3d0681bb3943454 No connection adapters were found for 'x-raw-image:///887b36b648062e2adb409efa85609394835b1076e321bf76e3d0681bb3943454'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:33<00:00]
#     </div>
# Error https://i.colnect.net/f/2340/165/King-Cobra-Ophiophagus-hannah.jpg ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7feb79d1ee80>, 'Connection to www.animogen.com timed out. (connect timeout=4)'))
# Error http://i40.photobucket.com/albums/e209/ilherps/kankakee%2005/EPV0012.jpg HTTPConnectionPool(host='i40.photobucket.com', port=80): Read timed out. (read timeout=4)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:25<00:00]
#     </div>
# Error https://www.registrelep-sararegistry.gc.ca/84444A56-E046-49A2-B31E-8FBB00133893/fig00.jpg HTTPSConnectionPool(host='www.registrelep-sararegistry.gc.ca', port=443): Max retries exceeded with url: /84444A56-E046-49A2-B31E-8FBB00133893/fig00.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')])")))
# Error x-raw-image:///3e3313ec2ed7b31f3da3de2b0549baf9a4d7250ffcf1b01438e00ff664b39d51 No connection adapters were found for 'x-raw-image:///3e3313ec2ed7b31f3da3de2b0549baf9a4d7250ffcf1b01438e00ff664b39d51'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:28<00:00]
#     </div>
# Error http://thesnake.review/wp-content/uploads/2018/06/snake-bite-common-ahaetulla-nasuta-is-a-slender-tree-rhalamycom-rough-youtuberhyoutubecom-rough-green-vine-snake-bite-youtuberhyoutubecom-guntherus-whip-oriental-asian.jpg HTTPConnectionPool(host='thesnake.review', port=80): Max retries exceeded with url: /wp-content/uploads/2018/06/snake-bite-common-ahaetulla-nasuta-is-a-slender-tree-rhalamycom-rough-youtuberhyoutubecom-rough-green-vine-snake-bite-youtuberhyoutubecom-guntherus-whip-oriental-asian.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7feb78cab3c8>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
# Error https://pinimg.icu/ipi/0x0/0263f/smiling-lil-green-snake-v-ahaetulla-nasuta-ganjam-orissa-india-E56fe62dac4cb1361e231bd76670f1a88.jpg HTTPSConnectionPool(host='pinimg.icu', port=443): Read timed out. (read timeout=4)
# Error https://cml.sad.ukrd.com/image/610897-1200x1200.jpg HTTPSConnectionPool(host='cml.sad.ukrd.com', port=443): Read timed out. (read timeout=4)
# Error https://thumbs-prod.si-cdn.com/EfYDlq_CCLYMXrFy-OJcT1QSTwc=/fit-in/1072x0/https://contest-public-media.smithsonianmag.com/0ab5f2f7-ee97-4942-a980-e75742040305.jpg HTTPSConnectionPool(host='thumbs-prod.si-cdn.com', port=443): Read timed out. (read timeout=4)

# %%
path = Path('data')
for c in classes:
    verify_images(path/c, delete=True, max_size=500)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='677' class='' max='677', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [677/677 00:28<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/venomous/00000257.svg'>
# cannot identify image file <_io.BufferedReader name='data/venomous/00000241.svg'>
# Image data/venomous/00000308.gif has 1 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000353.jpg'>
# Image data/venomous/00000049.png has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000031.JPG'>
# cannot identify image file <_io.BufferedReader name='data/venomous/00000133.jpg'>
# cannot identify image file <_io.BufferedReader name='data/venomous/00000219.jpeg'>
# Image data/venomous/00000228.gif has 1 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000197.jpg'>
# Image data/venomous/00000001.gif has 1 instead of 3
# Image data/venomous/00000392.png has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000252.JPG'>
# cannot identify image file <_io.BufferedReader name='data/venomous/00000293.jpg'>
# /home/siddhant/anaconda3/envs/fastai-v1/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file <_io.BufferedReader name='data/venomous/00000352.jpg'>
# Image data/venomous/00000378.gif has 1 instead of 3
# /home/siddhant/anaconda3/envs/fastai-v1/lib/python3.7/site-packages/PIL/Image.py:1005: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry " +
# int() argument must be a string, a bytes-like object or a number, not 'tuple'
# cannot identify image file <_io.BufferedReader name='data/venomous/00000365.jpg'>
# cannot identify image file <_io.BufferedReader name='data/venomous/00000344.jpg'>
# Image data/venomous/00000379.png has 4 instead of 3
# Image data/venomous/00000211.jpg has 1 instead of 3
# Image data/venomous/00000221.png has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000306.jpg'>
# Image data/venomous/00000360.png has 4 instead of 3
# Image data/venomous/00000011.gif has 1 instead of 3
# Image data/venomous/00000106.gif has 1 instead of 3
# Image data/venomous/00000250.png has 4 instead of 3
# Image data/venomous/00000074.png has 4 instead of 3
# Image data/venomous/00000158.png has 4 instead of 3
# Image data/venomous/00000189.png has 4 instead of 3
# Image data/venomous/00000094.png has 4 instead of 3
# Image data/venomous/00000343.jpg has 1 instead of 3
# Image data/venomous/00000367.png has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000322.jpg'>
# Image data/venomous/00000220.gif has 1 instead of 3
# Image data/venomous/00000236.png has 4 instead of 3
# Image data/venomous/00000245.png has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000230.jpg'>
# cannot identify image file <_io.BufferedReader name='data/venomous/00000035.jpg'>
# Image data/venomous/00000180.ppm has 1 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000138.JPG'>
# /home/siddhant/anaconda3/envs/fastai-v1/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# Image data/venomous/00000232.png has 4 instead of 3
# Image data/venomous/00000249.png has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/venomous/00000253.jpg'>
# Image data/venomous/00000353.png has 4 instead of 3
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='630' class='' max='630', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [630/630 00:23<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000353.jpg'>
# Image data/non_venomous/00000211.png has 1 instead of 3
# Image data/non_venomous/00000075.gif has 1 instead of 3
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000363.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000367.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000346.jpg'>
# Image data/non_venomous/00000273.png has 1 instead of 3
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000248.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000385.jpg'>
# /home/siddhant/anaconda3/envs/fastai-v1/lib/python3.7/site-packages/PIL/Image.py:1005: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry " +
# int() argument must be a string, a bytes-like object or a number, not 'tuple'
# Image data/non_venomous/00000004.png has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000163.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000213.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000189.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000154.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000041.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000214.jpg'>
# Image data/non_venomous/00000121.png has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000142.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000366.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000232.JPG'>
# Image data/non_venomous/00000331.gif has 1 instead of 3
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000207.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000285.jpg'>
# Image data/non_venomous/00000356.PNG has 4 instead of 3
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000397.jpg'>
# Image data/non_venomous/00000335.gif has 1 instead of 3
# Image data/non_venomous/00000326.png has 1 instead of 3
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000005.jpg'>
# cannot identify image file <_io.BufferedReader name='data/non_venomous/00000352.JPG'>

# %% [markdown]
# ## Looking at the data and loading them to a databunch

# %%
path = Path('data')
for c in classes:
    print(c, len(Path(path/c).ls()))
# Out:
# venomous 665
# non_venomous 621

# %%
np.random.seed(33)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=get_transforms(),
                                 size=299, num_workers=4, bs=32).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,7))

# %% [markdown]
# ## Simple training as this notebook's objective is dataset

# %%
learn = create_cnn(data, models.resnet50, metrics=accuracy)

# %%
learn.fit_one_cycle(2)
# Out:
# Total time: 01:09 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.501105</th>
#     <th>0.236577</th>
#     <th>0.894309</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.358079</th>
#     <th>0.230877</th>
#     <th>0.910569</th>
#   </tr>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9)

# %% [markdown]
# ## Cleaning up
# Some images are not realted to the dataset itself so we can prune them

# %%
from fastai.widgets import *

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
a = ImageCleaner(ds, idxs)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())
